# %%
 class Phone:
     categories="Electronics"

# %%
apple=Phone()
apple.category="super Electronics"
blueberry= Phone()
motorola= Phone()

print(apple.category)
print(blueberry.category)
print(motorola.category)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 apple=Phone()
#       2 apple.category="super Electronics"
#       3 blueberry= Phone()
#
# NameError: name 'Phone' is not defined
