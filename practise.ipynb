# %%
# converting temperature from celcius to  fahrenheit
import numpy as np
arr=np.array([1,2,3,4,5])
new_arr= [(x*1.8)+32 for x in arr]
print (new_arr)
# Out:
# [np.float64(33.8), np.float64(35.6), np.float64(37.4), np.float64(39.2), np.float64(41.0)]

# %%
arr=np.array([10, 20, 30, 40, 50, 35])
print(arr.shape)
print(arr.dtype)
print(arr.size)
new_arr=[(x/60) for x in arr]
print(new_arr)
# Out:
# (6,)
# int64
# 6
# [np.float64(0.16666666666666666), np.float64(0.3333333333333333), np.float64(0.5), np.float64(0.6666666666666666), np.float64(0.8333333333333334), np.float64(0.5833333333333334)]
